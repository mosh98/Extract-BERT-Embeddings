# %% [markdown]
# <a href="https://colab.research.google.com/github/mosh98/Extract-BERT-Embeddings/blob/main/Extract_BERT_EMBEDDINGS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Read more about Senetce BERT [here](https://www.sbert.net/)

# %% [markdown]
# # **STEP 1**

# %%
# !pip install -U sentence-transformers

# %% [markdown]
# # **STEP 2**

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('all-MiniLM-L6-v2')

# %% [markdown]
# # **STEP 3**

# %%
senetence = 'This sentence will generate '

embeddings = model.encode(senetence)

# %%
embeddings.shape
# Out:
# (384,)

# %%
embeddings
# Out:
# array([-5.44575378e-02,  6.03486672e-02, -5.59833227e-03,  7.28245378e-02,
#        -2.56153848e-02,  8.13938770e-03,  4.90968339e-02, -2.74244267e-02,
#         6.45990744e-02, -2.63483240e-03,  7.48219490e-02, -1.15867607e-01,
#         5.56440912e-02, -8.60123336e-02,  1.89723226e-03,  7.61161819e-02,
#         1.88891646e-02, -1.38752908e-02, -9.54100862e-02, -3.86093333e-02,
#         6.67370409e-02,  7.54399598e-02,  3.36904041e-02, -1.58141237e-02,
#        -2.85315216e-02, -5.40610589e-03, -2.03363900e-03,  4.84062806e-02,
#         1.50334552e-01, -6.88008359e-03,  1.63372122e-02,  3.41051780e-02,
#         1.25145325e-02,  1.58554483e-02,  1.85127149e-03,  3.09102908e-02,
#        -3.56052928e-02,  3.81396487e-02,  7.16491044e-02, -3.61994393e-02,
#        -4.12756018e-02, -1.34496376e-01,  2.28683520e-02,  6.90699741e-02,
#         4.02455069e-02, -3.21880877e-02, -2.69051418e-02,  3.97382379e-02,
# ...
